# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa = pd.read_csv(r"C:\Users\chait\session_code\GratLearning\players_20.csv")

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa.describe
# Out:
# <bound method NDFrame.describe of        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# ...

# %%
fifa.info
# Out:
# <bound method DataFrame.info of        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# ...

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
fifa['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: nationality, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
plt.figure(figsize=(10,10))
plt.bar(list(fifa['nationality'].value_counts()[0:10].keys()), list(fifa['nationality'].value_counts()[0:10]),color='purple')
plt.show()

# %%
player_salary = fifa[['short_name', 'wage_eur', 'value_eur']]

# %%
player_salary.head(10)
# Out:
#           short_name  wage_eur  value_eur
# 0           L. Messi    565000   95500000
# 1  Cristiano Ronaldo    405000   58500000
# 2          Neymar Jr    290000  105500000
# 3           J. Oblak    125000   77500000
# 4          E. Hazard    470000   90000000
# 5       K. De Bruyne    370000   90000000
# 6      M. ter Stegen    250000   67500000
# 7        V. van Dijk    200000   78000000
# 8          L. Modrić    340000   45000000
# 9           M. Salah    240000   80500000

# %%
player_salary = player_salary.sort_values(by='wage_eur', ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur  value_eur
# 0            L. Messi    565000   95500000
# 4           E. Hazard    470000   90000000
# 1   Cristiano Ronaldo    405000   58500000
# 5        K. De Bruyne    370000   90000000
# 22       A. Griezmann    370000   69000000

# %%
plt.figure(figsize=(10,10))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5], color=['blue','yellow','pink','orange','purple'])
plt.show()

# %%
list(player_salary['short_name'])[0:5], list(player_salary['wage_eur'])[0:5]
# Out:
# (['L. Messi', 'Cristiano Ronaldo', 'Neymar Jr', 'J. Oblak', 'E. Hazard'],
#  [565000, 405000, 290000, 125000, 470000])

# %%
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Germany = fifa[fifa['nationality']=='Germany']

# %%
Germany.head(100)
# Out:
#       sofifa_id                                         player_url  \
# 6        192448  https://sofifa.com/player/192448/marc-andre-te...
# 31       167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36       182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37       188350  https://sofifa.com/player/188350/marco-reus/20...
# 49       178603  https://sofifa.com/player/178603/mats-hummels/...
# ...         ...                                                ...
# 1448     158138  https://sofifa.com/player/158138/aaron-hunt/20...
# 1495     183714  https://sofifa.com/player/183714/simon-terodde...
# 1516     188802  https://sofifa.com/player/188802/marcel-schmel...
# 1525     190520  https://sofifa.com/player/190520/tony-jantschk...
# 1536     193130  https://sofifa.com/player/193130/andre-schurrl...
#
#          short_name              long_name  age         dob  height_cm  \
# 6     M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# ...

# %%
Germany.sort_values(by='height_cm', ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# ...          ...                                                ...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 6364      189209  https://sofifa.com/player/189209/sascha-bigalk...
# 15960     247284  https://sofifa.com/player/247284/patrick-finge...
# 11380     250936  https://sofifa.com/player/250936/seref-ozcan/2...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# ...

# %%
Germany.sort_values(by='weight_kg', ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# ...          ...                                                ...
# 17276     248583  https://sofifa.com/player/248583/sinisa-spreca...
# 11612     248879  https://sofifa.com/player/248879/kevin-holzwei...
# 13387     252559  https://sofifa.com/player/252559/volkan-egri/2...
# 17889     239129  https://sofifa.com/player/239129/jakob-gesien/...
# 17879     244094  https://sofifa.com/player/244094/leonard-langh...
#
#            short_name           long_name  age         dob  height_cm  \
# 13576    L. Watkowiak     Lukas Watkowiak   23  1996-03-06        197
# ...

# %%
Germany_wage = Germany.sort_values(by='wage_eur',ascending=False)
Germany_wage=Germany_wage[['short_name', 'wage_eur', 'height_cm', 'weight_kg']]

# %%
Germany_wage
# Out:
#           short_name  wage_eur  height_cm  weight_kg
# 36          T. Kroos    330000        183         76
# 6      M. ter Stegen    250000        187         85
# 55           L. Sané    195000        183         75
# 146      I. Gündoğan    180000        180         80
# 70         T. Müller    170000        186         75
# ...              ...       ...        ...        ...
# 13488  J. Gerezgiher      1000        176         71
# 13463       T. Bonga      1000        196         89
# 13458      L. Jensen      1000        175         70
# 13373    L. Gottwalt      1000        192         84
# 18197     M. Harsman      1000        190         80
#
# [1216 rows x 4 columns]

# %%
jensen = fifa[fifa['short_name']=='L. Jensen']

# %%
jensen
# Out:
#        sofifa_id                                         player_url  \
# 13458     238792  https://sofifa.com/player/238792/leon-jensen/2...
#
#       short_name    long_name  age         dob  height_cm  weight_kg  \
# 13458  L. Jensen  Leon Jensen   22  1997-05-19        175         70
#
#       nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 13458     Germany  FSV Zwickau  ...  48+2  44+2  44+2  44+2  48+2  45+2  36+2
#
#          cb   rcb    rb
# 13458  36+2  36+2  45+2
#
# [1 rows x 104 columns]

# %% [markdown]
# # SHOOTING

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
fifa['shooting']
# Out:
# 0        92.0
# 1        93.0
# 2        85.0
# 3         NaN
# 4        83.0
#          ...
# 18273    23.0
# 18274    24.0
# 18275    35.0
# 18276    35.0
# 18277    32.0
# Name: shooting, Length: 18278, dtype: float64

# %%
player_shooting=player_shooting.sort_values(by= 'shooting', ascending=False)

# %%
player_shooting.head(20)
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0
# 19           L. Suárez      89.0
# 96      Z. Ibrahimović      88.0
# 37             M. Reus      88.0
# 100            G. Bale      87.0
# 20      R. Lewandowski      87.0
# 9             M. Salah      86.0
# 106       J. Rodríguez      86.0
# 34           E. Cavani      86.0
# 5         K. De Bruyne      86.0
# 22        A. Griezmann      86.0
# 43              H. Son      86.0
# 98          G. Higuaín      85.0
# 71         C. Immobile      85.0
# 233        A. Kramarić      85.0
# 532               Hulk      85.0

# %%
player_shooting = fifa[['short_name', 'shooting']]

# %% [markdown]
# # defending

# %%
player_defending = fifa[['short_name', 'defending', 'nationality', 'club']]

# %%
player_defending.head()
# Out:
#           short_name  defending nationality                 club
# 0           L. Messi       39.0   Argentina         FC Barcelona
# 1  Cristiano Ronaldo       35.0    Portugal             Juventus
# 2          Neymar Jr       32.0      Brazil  Paris Saint-Germain
# 3           J. Oblak        NaN    Slovenia      Atlético Madrid
# 4          E. Hazard       35.0     Belgium          Real Madrid

# %%
player_india = fifa[fifa['nationality']=='India']

# %%
player_india[['value_eur','wage_eur', 'club']]
# Out:
#        value_eur  wage_eur   club
# 12155          0         0  India
# 13102          0         0  India
# 13103          0         0  India
# 13970          0         0  India
# 13971          0         0  India
# 13972          0         0  India
# 14625          0         0  India
# 15204          0         0  India
# 15205          0         0  India
# 15321          0         0  India
# 15322          0         0  India
# 15323          0         0  India
# 15324          0         0  India
# 15809          0         0  India
# 15866          0         0  India
# 15867          0         0  India
# 15868          0         0  India
# 16300          0         0  India
# 16303          0         0  India
# 16352          0         0  India
# 16353          0         0  India
# 16354          0         0  India
# 16714          0         0  India

# %%
player_india
# Out:
#        sofifa_id                                         player_url  \
# 12155     251742  https://sofifa.com/player/251742/gajodara-chat...
# 13102     251723  https://sofifa.com/player/251723/prakul-bhatt/...
# 13103     251728  https://sofifa.com/player/251728/bhadrashree-r...
# 13970     251722  https://sofifa.com/player/251722/abhimoda-chak...
# 13971     251727  https://sofifa.com/player/251727/hantidev-bhan...
# 13972     251736  https://sofifa.com/player/251736/anvit-swamina...
# 14625     251729  https://sofifa.com/player/251729/devindra-pill...
# 15204     251743  https://sofifa.com/player/251743/adit-ginti/20...
# 15205     251747  https://sofifa.com/player/251747/anuvinda-khur...
# 15321     251721  https://sofifa.com/player/251721/attana-deshpa...
# 15322     251725  https://sofifa.com/player/251725/tapish-atwal/...
# 15323     251731  https://sofifa.com/player/251731/bismeet-sidhu...
# 15324     251732  https://sofifa.com/player/251732/remil-nadkarn...
# ...

# %%
fifa['club'].value_counts()
# Out:
# FC Barcelona                  33
# Real Valladolid CF            33
# VfL Wolfsburg                 33
# Crystal Palace                33
# Eintracht Frankfurt           33
#                               ..
# US Orléans Loiret Football     1
# Canada                         1
# Mexico                         1
# Turkey                         1
# Śląsk Wrocław                  1
# Name: club, Length: 698, dtype: int64

# %%
real_madrid = fifa[fifa['club']=='Real Madrid']

# %%
real_madrid
# Out:
#        sofifa_id                                         player_url  \
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 28        192119  https://sofifa.com/player/192119/thibaut-court...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 53        193041  https://sofifa.com/player/193041/keylor-navas/...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# ...

# %%
real_madrid = real_madrid.sort_values(by='wage_eur', ascending=False)

# %%
real_madrid[['short_name','wage_eur']]
# Out:
#             short_name  wage_eur
# 4            E. Hazard    470000
# 8            L. Modrić    340000
# 36            T. Kroos    330000
# 18        Sergio Ramos    300000
# 46          K. Benzema    285000
# 100            G. Bale    250000
# 62                Isco    245000
# 42            Casemiro    240000
# 28         T. Courtois    235000
# 106       J. Rodríguez    225000
# 76           R. Varane    205000
# 94            Carvajal    205000
# 101            Marcelo    205000
# 53            K. Navas    195000
# 403      Lucas Vázquez    180000
# 178      Marco Asensio    180000
# 277    Nacho Fernández    165000
# 161           L. Jović    155000
# 636            Mariano    145000
# 424           F. Mendy    115000
# 437          Odriozola    115000
# 332       Éder Militão    105000
# 2286       Lucas Silva     88000
# 1009       F. Valverde     86000
# 568       Vinícius Jr.     60000
# 2652            Brahim     58000
# 1256           Rodrygo     47000
# ...

# %%
real_madrid.sort_values(by='shooting',ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 100       173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106       198710  https://sofifa.com/player/198710/james-rodrigu...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46        165153  https://sofifa.com/player/165153/karim-benzema...
# 161       232432  https://sofifa.com/player/232432/luka-jovic/20...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 178       220834  https://sofifa.com/player/220834/marco-asensio...
# 636       221639  https://sofifa.com/player/221639/mariano-diaz-...
# 62        197781  https://sofifa.com/player/197781/francisco-rom...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# 403       208618  https://sofifa.com/player/208618/lucas-vazquez...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# ...

# %%
real_madrid.sort_values(by='defending', ascending=False)
# Out:
#        sofifa_id                                         player_url  \
# 18        155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42        200145  https://sofifa.com/player/200145/carlos-henriq...
# 76        201535  https://sofifa.com/player/201535/raphael-varan...
# 94        204963  https://sofifa.com/player/204963/daniel-carvaj...
# 277       200724  https://sofifa.com/player/200724/jose-ignacio-...
# 332       240130  https://sofifa.com/player/240130/eder-gabriel-...
# 437       234035  https://sofifa.com/player/234035/alvaro-odrioz...
# 101       176676  https://sofifa.com/player/176676/marcelo-vieir...
# 424       228618  https://sofifa.com/player/228618/ferland-mendy...
# 8         177003  https://sofifa.com/player/177003/luka-modric/2...
# 2286      209749  https://sofifa.com/player/209749/lucas-silva-b...
# 36        182521  https://sofifa.com/player/182521/toni-kroos/20...
# 5676      244523  https://sofifa.com/player/244523/javier-hernan...
# ...

# %%
real_madrid['nationality'].value_counts()
# Out:
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Wales                  1
# Colombia               1
# Costa Rica             1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: nationality, dtype: int64

# %%
player_barcelona = fifa[fifa['club']=='FC Barcelona']

# %%
player_barcelona[player_barcelona['nationality']=='India']
# Out:
# Empty DataFrame
# ...
